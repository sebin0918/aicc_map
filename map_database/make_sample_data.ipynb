# %%
from datetime import datetime
import pandas as pd
import os

file_path = './datas'
if not os.path.exists(file_path):
    os.makedirs(file_path)

# Sample data for tb_user_key
tb_user_key_data = {
    'user_id': [1, 2, 3, 4, 5],
    'uk_email': ['user1@example.com', 'user2@example.com', 'user3@example.com', 'user4@example.com', 'user5@example.com'],
    'uk_password': ['password1', 'password2', 'password3', 'password4', 'password5'],
    'uk_permission': [1, 1, 0, 1, 0]
}

# sample data for tb_user_information
tb_user_information_data = {
    'user_id': [1, 2, 3, 4, 5],
    'ui_name': ['User One', 'User Two', 'User Three', 'User Four', 'User Five'],
    'ui_birth_date': ['1990-01-01', '1985-02-15', '1995-03-30', '1980-04-25', '2000-05-20'],
    'ui_sex': [1, 0, 1, 0, 1],
    'ui_bank_num': ['1234567890', '1234567891', '1234567892', '1234567893', '1234567894'],
    'ui_caution': [0, 0, 0, 0, 0],
    'ui_phone_number': ['010-123-123', '010-123-234', '010-123-345', '010-234-123', '010-234-234']
}

# sample data for tb_finance
tb_user_finance_data = {
    'user_id': [1, 2, 3, 4, 5],
    'uf_capital': [10000, 20000, 15000, 25000, 5000],
    'uf_loan': [5000, 10000, 7500, 12000, 2000],
    'uf_installment_saving': [2000, 5000, 3000, 8000, 1000],
    'uf_deposit': [3000, 10000, 6000, 12000, 2000],
    'uf_target_budget': [15000, 30000, 22500, 40000, 8000]
}

# Sample data for tb_chat_bot
tb_chat_bot_data = {
    'cb_id': [1, 2, 3, 4, 5],
    'user_id': [1, 2, 3, 4, 5],
    'cb_date': ['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04', '2024-01-05'],
    'cb_text': ['Welcome to the chat bot.', 'How can I assist you today?', 'Here is the information you requested.', 'Have a nice day!', 'Goodbye!']
}

# Sample data for tb_stock_predict
tb_stock_predict_data = {
    'sp_id': [1, 2, 3, 4, 5],
    'sp_date': ['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04', '2024-01-05'],
    'sp_ss_predict': [55, 56, 57, 58, 59],
    'sp_ap_predict': [65, 66, 67, 68, 69],
    'sp_bit_predict': [35, 54, 78, 54, 66]
}

# Sample data for tb_shares_held
tb_shares_held_data = {
    'sh_id': [1, 2, 3, 4, 5],
    'user_id': [1, 2, 3, 4, 5],
    'sc_id': [1, 2, 3, 4, 5],
    'sh_date': ['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04', '2024-01-05'],
    'sh_ss_count': [10, 20, 30, 40, 50],
    'sh_ap_count': [15, 25, 35, 45, 55],
    'sh_bit_count': [12, 33, 22, 15, 23]
}

# Sample data for tb_received_paid
tb_received_paid_data = {
    'rp_id': [1, 2, 3, 4, 5],
    'user_id': [1, 2, 3, 4, 5],
    'rp_date': ['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04', '2024-01-05'],
    'rp_detail': ['Salary', 'Bonus', 'Dividend', 'Sale', 'Interest'],
    'rp_amount': [1000, 2000, 1500, 2500, 500],
    'rp_hold': [1, 0, 1, 0, 1],
    'rp_part': [0, 1, 0, 1, 0]
}

# Sample data for tb_news
tb_news_data = {
    'news_id': [1, 2, 3, 4, 5],
    'news_date': ['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04', '2024-01-05'],
    'news_title': ['Title 1', 'Title 2', 'Title 3', 'Title 4', 'Title 5'],
    'news_simple_text': ['Text 1', 'Text 2', 'Text 3', 'Text 4', 'Text 5'],
    'news_link': ['http://example.com/1', 'http://example.com/2', 'http://example.com/3', 'http://example.com/4', 'http://example.com/5']
}

# Sample data for tb_news_chat_room
tb_news_chat_room_data = {
    'ncr_id': [1, 2, 3, 4, 5],
    'news_id': [1, 2, 3, 4, 5],
    'ncr_chat_message': ['Message 1', 'Message 2', 'Message 3', 'Message 4', 'Message 5'],
    'ncr_timestamp': [datetime.now(), datetime.now(), datetime.now(), datetime.now(), datetime.now()]
}

# Sample data for tb_faq
tb_faq_data = {
    'faq_id': [1, 2, 3, 4, 5],
    'faq_type': ['General', 'Account', 'Payment', 'Technical', 'Other'],
    'faq_ask': ['What is your name?', 'How to reset password?', 'How to make a payment?', 'Why is my account locked?', 'Who can I contact for support?'],
    'faq_answer': ['My name is Bot.', 'Go to settings to reset password.', 'Use the payment gateway.', 'Contact support to unlock your account.', 'Contact us at support@example.com.']
}



# Create DataFrames
tb_user_key_df = pd.DataFrame(tb_user_key_data)
tb_user_information_df = pd.DataFrame(tb_user_information_data)
tb_user_finance_df = pd.DataFrame(tb_user_finance_data)
tb_chat_bot_df = pd.DataFrame(tb_chat_bot_data)
tb_stock_predict_df = pd.DataFrame(tb_stock_predict_data)
tb_shares_held_df = pd.DataFrame(tb_shares_held_data)
tb_received_paid_df = pd.DataFrame(tb_received_paid_data)
tb_news_df = pd.DataFrame(tb_news_data)
tb_news_chat_room_df = pd.DataFrame(tb_news_chat_room_data)
tb_faq_df = pd.DataFrame(tb_faq_data)


# Save DataFrames to Excel
tb_user_key_df.to_excel(os.path.join(file_path, 'tb_user_key.xlsx'), index=False)
tb_user_information_df.to_excel(os.path.join(file_path, 'tb_user_information.xlsx'), index=False)
tb_user_finance_df.to_excel(os.path.join(file_path, 'tb_user_finance.xlsx'), index=False)
tb_chat_bot_df.to_excel(os.path.join(file_path, 'tb_chat_bot.xlsx'), index=False)
tb_stock_predict_df.to_excel(os.path.join(file_path, 'tb_stock_predict.xlsx'), index=False)
tb_shares_held_df.to_excel(os.path.join(file_path, 'tb_shares_held.xlsx'), index=False)
tb_received_paid_df.to_excel(os.path.join(file_path, 'tb_received_paid.xlsx'), index=False)
tb_news_df.to_excel(os.path.join(file_path, 'tb_news.xlsx'), index=False)
tb_news_chat_room_df.to_excel(os.path.join(file_path, 'tb_news_chat_room.xlsx'), index=False)
tb_faq_df.to_excel(os.path.join(file_path, 'tb_faq.xlsx'), index=False)
# Out:
# C:\Users\reals\AppData\Local\Temp\ipykernel_14048\2591833777.py:115: UserWarning: Pandas requires version '3.0.5' or newer of 'xlsxwriter' (version '3.0.3' currently installed).
#   tb_user_key_df.to_excel(os.path.join(file_path, 'tb_user_key.xlsx'), index=False)
# C:\Users\reals\AppData\Local\Temp\ipykernel_14048\2591833777.py:116: UserWarning: Pandas requires version '3.0.5' or newer of 'xlsxwriter' (version '3.0.3' currently installed).
#   tb_user_information_df.to_excel(os.path.join(file_path, 'tb_user_information.xlsx'), index=False)
# C:\Users\reals\AppData\Local\Temp\ipykernel_14048\2591833777.py:117: UserWarning: Pandas requires version '3.0.5' or newer of 'xlsxwriter' (version '3.0.3' currently installed).
#   tb_user_finance_df.to_excel(os.path.join(file_path, 'tb_user_finance.xlsx'), index=False)
# ...
